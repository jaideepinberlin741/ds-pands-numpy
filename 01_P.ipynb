# %%
import pandas as pd # We haven't actually done this in code yet. 
data_lst = [{'a': 1, 'b': 2, 'c':3}, {'a': 4, 'b':5, 'c':6, 'd':7}]
df = pd.DataFrame(data_lst) 
df
# Out:
#    a  b  c    d
# 0  1  2  3  NaN
# 1  4  5  6  7.0

# %%
data_lst = [{'a': 1}, {'b':5}, {'c': 4}]
df = pd.DataFrame(data_lst)

# %%
df
# Out:
#      a    b    c
# 0  1.0  NaN  NaN
# 1  NaN  5.0  NaN
# 2  NaN  NaN  4.0

# %%
data_vals = [[1, 2, 3], [4, 5, 6]]
data_cols = ['a', 'b', 'c']
df = pd.DataFrame(data=data_vals, columns=data_cols)
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
data_vals = [[1, 2], [4, 5, 6]]
data_cols = ['a', 'b','c']
df = pd.DataFrame(data=data_vals, columns=data_cols)
df
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  4  5  6.0

# %%
df = pd.read_csv("data/abalone.csv")

# %%
df.head()
# Out:
#   sex  length  diameter  height  weight_whole  weight_shucked  viscera  shell  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245   0.1010  0.150
# 1   M   0.350     0.265   0.090        0.2255          0.0995   0.0485  0.070
# 2   F   0.530     0.420   0.135        0.6770          0.2565   0.1415  0.210
# 3   M   0.440     0.365   0.125        0.5160          0.2155   0.1140  0.155
# 4   I   0.330     0.255   0.080        0.2050          0.0895   0.0395  0.055
#
#    n_rings
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7

# %%
df.tail()
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700   0.2390
# 4173   M   0.590     0.440   0.135        0.9660          0.4390   0.2145
# 4174   M   0.600     0.475   0.205        1.1760          0.5255   0.2875
# 4175   F   0.625     0.485   0.150        1.0945          0.5310   0.2610
# 4176   M   0.710     0.555   0.195        1.9485          0.9455   0.3765
#
#        shell  n_rings
# 4172  0.2490       11
# 4173  0.2605       10
# 4174  0.3080        9
# 4175  0.2960       10
# 4176  0.4950       12

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sex             4177 non-null   object
#  1   length          4177 non-null   float64
#  2   diameter        4177 non-null   float64
#  3   height          4177 non-null   float64
#  4   weight_whole    4177 non-null   float64
#  5   weight_shucked  4177 non-null   float64
#  6   viscera         4177 non-null   float64
#  7   shell           4177 non-null   float64
#  8   n_rings         4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.describe()
# Out:
#             length     diameter       height  weight_whole  weight_shucked  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#            viscera        shell      n_rings
# count  4177.000000  4177.000000  4177.000000
# mean      0.180594     0.238831     9.933684
# std       0.109614     0.139203     3.224169
# min       0.000500     0.001500     1.000000
# 25%       0.093500     0.130000     8.000000
# 50%       0.171000     0.234000     9.000000
# 75%       0.253000     0.329000    11.000000
# max       0.760000     1.005000    29.000000

# %%
# Grabs the "sex" column: bracket notation
df['sex']
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: sex, Length: 4177, dtype: object

# %%
# Grabs the "sex" column: dot notation
df.sex
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: sex, Length: 4177, dtype: object

# %%
# make a copy of your DataFrame
df2 = df.copy()
# make a list column names
cols = df2.columns.tolist()
# replace space with _
cols = [col.replace(' ', '_') for col in cols]
# reassign new column names to DataFrame
df2.columns = cols

# %%
df[['sex', 'length']]
# Out:
#      sex  length
# 0      M   0.455
# 1      M   0.350
# 2      F   0.530
# 3      M   0.440
# 4      I   0.330
# ...   ..     ...
# 4172   F   0.565
# 4173   M   0.590
# 4174   M   0.600
# 4175   F   0.625
# 4176   M   0.710
#
# [4177 rows x 2 columns]

# %%
# This will grab from the beginning up to but not including the row at index 3. 
df[:3]
# Out:
#   sex  length  diameter  height  weight_whole  weight_shucked  viscera  shell  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245   0.1010   0.15
# 1   M   0.350     0.265   0.090        0.2255          0.0995   0.0485   0.07
# 2   F   0.530     0.420   0.135        0.6770          0.2565   0.1415   0.21
#
#    n_rings
# 0       15
# 1        7
# 2        9

# %%
# Loc is label based. All of these will work, because they are recognized as labels on the 
# rows (index labels) or columns (column name labels). 
df.loc[0, 'sex'] # 0 is one of the index labels, and 'sex' is a column label.
# Out:
# 'M'

# %%
# Ranges on our index labels still work (as long as they're numeric).
df.loc[0:10, 'sex']
# Out:
# 0     M
# 1     M
# 2     F
# 3     M
# 4     I
# 5     I
# 6     F
# 7     F
# 8     M
# 9     F
# 10    F
# Name: sex, dtype: object

# %%
df.loc[10:15, ['sex', 'length']]
# Out:
#    sex  length
# 10   F   0.525
# 11   M   0.430
# 12   M   0.490
# 13   F   0.535
# 14   F   0.470
# 15   M   0.500

# %%
# The above will all work with .iloc, though, since it takes integers (and not labels)
df.iloc[0, 0]
df.iloc[0:10, 0]
df.iloc[10:15, [0, 4]]
# Out:
#    sex  weight_whole
# 10   F        0.6065
# 11   M        0.4060
# 12   M        0.5415
# 13   F        0.6845
# 14   F        0.4755

# %%
# This just gives us a mask - tells us True or False whether each row fit's the condition.
df['length'] <= 0.4
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 4172    False
# 4173    False
# 4174    False
# 4175    False
# 4176    False
# Name: length, Length: 4177, dtype: bool

# %%
# To use a mask, we actually have to use it to index into the DataFrame (using square brackets). 
df[df['length'] <= 0.4]
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 1      M   0.350     0.265   0.090        0.2255          0.0995   0.0485
# 4      I   0.330     0.255   0.080        0.2050          0.0895   0.0395
# 16     I   0.355     0.280   0.085        0.2905          0.0950   0.0395
# 18     M   0.365     0.295   0.080        0.2555          0.0970   0.0430
# 20     M   0.355     0.280   0.095        0.2455          0.0955   0.0620
# ...   ..     ...       ...     ...           ...             ...      ...
# 4151   I   0.350     0.250   0.075        0.1695          0.0835   0.0355
# 4152   I   0.370     0.280   0.090        0.2180          0.0995   0.0545
# 4162   M   0.385     0.255   0.100        0.3175          0.1370   0.0680
# 4163   I   0.390     0.310   0.085        0.3440          0.1810   0.0695
# 4164   I   0.390     0.290   0.100        0.2845          0.1255   0.0635
#
#        shell  n_rings
# 1     0.0700        7
# 4     0.0550        7
# 16    0.1150        7
# 18    0.1000        7
# 20    0.0750       11
# ...      ...      ...
# 4151  0.0410        6
# 4152  0.0615        7
# 4162  0.0920        8
# 4163  0.0790        7
# 4164  0.0810        7
#
# [695 rows x 9 columns]

# %%
# Okay, this is cool. What if I wanted a slightly more complicated query...
df[(df['length'] <= 0.4) & (df['sex'] == 'F')]
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 71     F   0.400     0.320   0.110        0.3530          0.1405   0.0985
# 132    F   0.325     0.260   0.090        0.1915          0.0850   0.0360
# 136    F   0.305     0.230   0.080        0.1560          0.0675   0.0345
# 226    F   0.390     0.290   0.125        0.3055          0.1210   0.0820
# 331    F   0.400     0.325   0.120        0.3185          0.1340   0.0565
# 514    F   0.275     0.195   0.070        0.0800          0.0310   0.0215
# 519    F   0.345     0.250   0.090        0.2030          0.0780   0.0590
# 521    F   0.360     0.270   0.090        0.1885          0.0845   0.0385
# 539    F   0.375     0.290   0.115        0.2705          0.0930   0.0660
# 544    F   0.380     0.290   0.105        0.2570          0.0990   0.0510
# 591    F   0.370     0.290   0.115        0.2500          0.1110   0.0570
# 601    F   0.385     0.315   0.110        0.2860          0.1225   0.0635
# 602    F   0.390     0.300   0.100        0.2650          0.1075   0.0600
# 627    F   0.380     0.305   0.095        0.2815          0.1255   0.0525
# 654    F   0.370     0.280   0.110        0.2305          0.0945   0.0465
# 663    F   0.380     0.305   0.105        0.2810          0.1045   0.0615
# 665    F   0.395     0.295   0.095        0.2245          0.0780   0.0540
# 679    F   0.370     0.275   0.100        0.2225          0.0930   0.0260
# 699    F   0.395     0.315   0.105        0.3515          0.1185   0.0910
# 707    F   0.345     0.260   0.090        0.2070          0.0775   0.0435
# 741    F   0.360     0.265   0.090        0.2065          0.0780   0.0570
# 1766   F   0.375     0.270   0.135        0.5970          0.2720   0.1310
# 2044   F   0.400     0.305   0.160        0.3680          0.1730   0.0705
# 2099   F   0.400     0.310   0.115        0.3465          0.1475   0.0695
# 2117   F   0.375     0.290   0.080        0.2820          0.1405   0.0725
# 2123   F   0.290     0.210   0.075        0.2750          0.1130   0.0675
# 2152   F   0.400     0.300   0.115        0.3025          0.1335   0.0465
# 2167   F   0.370     0.275   0.085        0.2405          0.1040   0.0535
# 2206   F   0.290     0.225   0.075        0.1400          0.0515   0.0235
# 2246   F   0.380     0.325   0.110        0.3105          0.1200   0.0740
# 2287   F   0.385     0.305   0.105        0.3315          0.1365   0.0745
# 2292   F   0.380     0.300   0.090        0.3215          0.1545   0.0750
# 2379   F   0.360     0.265   0.090        0.2165          0.0960   0.0370
# 2439   F   0.345     0.255   0.100        0.1970          0.0710   0.0510
# 2448   F   0.350     0.265   0.090        0.1855          0.0745   0.0415
# 2449   F   0.370     0.285   0.105        0.2700          0.1125   0.0585
# 2468   F   0.370     0.275   0.080        0.2270          0.0930   0.0625
# 2501   F   0.330     0.260   0.080        0.2000          0.0625   0.0500
# 3159   F   0.340     0.255   0.085        0.2040          0.0970   0.0210
# 3161   F   0.335     0.220   0.070        0.1700          0.0760   0.0365
# 3180   F   0.370     0.295   0.100        0.2685          0.1165   0.0560
# 3201   F   0.385     0.300   0.100        0.2725          0.1115   0.0570
# 3267   F   0.400     0.335   0.115        0.4335          0.2105   0.1205
# 3323   F   0.395     0.300   0.105        0.3375          0.1435   0.0755
# 3330   F   0.385     0.305   0.125        0.3140          0.1460   0.0555
# 3384   F   0.305     0.225   0.070        0.1485          0.0585   0.0335
# 3720   F   0.380     0.320   0.115        0.6475          0.3230   0.1325
# 3850   F   0.375     0.295   0.110        0.3005          0.1255   0.0575
# 3938   F   0.350     0.275   0.065        0.2050          0.0745   0.0465
#
#        shell  n_rings
# 71    0.1000        8
# 132   0.0620        7
# 136   0.0480        7
# 226   0.0900        7
# 331   0.0950        8
# 514   0.0250        5
# 519   0.0550        6
# 521   0.0550        5
# 539   0.0885       10
# 544   0.0850       10
# 591   0.0750        9
# 601   0.0835       10
# 602   0.0865       13
# 627   0.0900        8
# 654   0.0750       10
# 663   0.0900       12
# 665   0.0800       10
# 679   0.0800        8
# 699   0.1195       16
# 707   0.0765       10
# 741   0.0600        8
# 1766  0.1675        7
# 2044  0.1050        7
# 2099  0.1150       10
# 2117  0.0800        7
# 2123  0.0350        6
# 2152  0.0935        8
# 2167  0.0700        5
# 2206  0.0400        5
# 2246  0.1050       10
# 2287  0.1000        7
# 2292  0.0950        9
# 2379  0.0735       10
# 2439  0.0600        9
# 2448  0.0600        7
# 2449  0.0835        9
# 2468  0.0700        8
# 2501  0.0700        9
# 3159  0.0500        6
# 3161  0.0500        6
# 3180  0.0835        7
# 3201  0.0800        6
# 3267  0.1200       10
# 3323  0.0980       12
# 3330  0.0800       10
# 3384  0.0450        7
# 3720  0.1640        7
# 3850  0.1035        7
# 3938  0.0700       10

# %%
# So I could write an arbitrarily complicated query using that syntax... 
df[(df['length'] <= 0.4) & (df['length'] > 0.35) & (df['weight_whole'] > 0.25) & (df['weight_whole'] < 0.3)]
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 16     I   0.355     0.280   0.085        0.2905          0.0950   0.0395
# 18     M   0.365     0.295   0.080        0.2555          0.0970   0.0430
# 121    I   0.385     0.295   0.085        0.2535          0.1030   0.0575
# 127    I   0.385     0.290   0.085        0.2505          0.1120   0.0610
# 139    M   0.375     0.285   0.095        0.2530          0.0960   0.0575
# ...   ..     ...       ...     ...           ...             ...      ...
# 3923   M   0.395     0.280   0.080        0.2660          0.0995   0.0660
# 3968   I   0.375     0.290   0.095        0.2875          0.1230   0.0605
# 3969   I   0.380     0.300   0.090        0.2770          0.1655   0.0625
# 3971   I   0.400     0.295   0.095        0.2520          0.1105   0.0575
# 4164   I   0.390     0.290   0.100        0.2845          0.1255   0.0635
#
#        shell  n_rings
# 16    0.1150        7
# 18    0.1000        7
# 121   0.0850        7
# 127   0.0800        8
# 139   0.0925        9
# ...      ...      ...
# 3923  0.0900       12
# 3968  0.0800        6
# 3969  0.0820        6
# 3971  0.0660        6
# 4164  0.0810        7
#
# [86 rows x 9 columns]

# %%
# Or I could use the query() method that is available on our DataFrame object. 
df.query('length <= 0.4 and length > 0.35 and weight_whole > 0.25 and weight_whole < 0.3')
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 16     I   0.355     0.280   0.085        0.2905          0.0950   0.0395
# 18     M   0.365     0.295   0.080        0.2555          0.0970   0.0430
# 121    I   0.385     0.295   0.085        0.2535          0.1030   0.0575
# 127    I   0.385     0.290   0.085        0.2505          0.1120   0.0610
# 139    M   0.375     0.285   0.095        0.2530          0.0960   0.0575
# ...   ..     ...       ...     ...           ...             ...      ...
# 3923   M   0.395     0.280   0.080        0.2660          0.0995   0.0660
# 3968   I   0.375     0.290   0.095        0.2875          0.1230   0.0605
# 3969   I   0.380     0.300   0.090        0.2770          0.1655   0.0625
# 3971   I   0.400     0.295   0.095        0.2520          0.1105   0.0575
# 4164   I   0.390     0.290   0.100        0.2845          0.1255   0.0635
#
#        shell  n_rings
# 16    0.1150        7
# 18    0.1000        7
# 121   0.0850        7
# 127   0.0800        8
# 139   0.0925        9
# ...      ...      ...
# 3923  0.0900       12
# 3968  0.0800        6
# 3969  0.0820        6
# 3971  0.0660        6
# 4164  0.0810        7
#
# [86 rows x 9 columns]

# %%
# first we try to groupby the sex, let's check how many different values this feature can have 
df['sex'].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
# we can also see the count of different values with this command
df['sex'].nunique()
# Out:
# 3

# %%
df.groupby('sex')   # Note that this returns back to us a groupby object. It doesn't actually 
                    # return to us anything useful until we perform some aggregation on it.

# %%
# Group by sex column
groupby_obj = df.groupby('sex')

# Performing an aggregation by calculating the mean
groupby_obj.mean()
# Out:
#        length  diameter    height  weight_whole  weight_shucked   viscera  \
# sex
# F    0.579093  0.454732  0.158011      1.046532        0.446188  0.230689
# I    0.427746  0.326494  0.107996      0.431363        0.191035  0.092010
# M    0.561391  0.439287  0.151381      0.991459        0.432946  0.215545
#
#         shell    n_rings
# sex
# F    0.302010  11.129304
# I    0.128182   7.890462
# M    0.281969  10.705497

# %%
groupby_obj.max()
# Out:
#      length  diameter  height  weight_whole  weight_shucked  viscera  shell  \
# sex
# F     0.815      0.65   1.130        2.6570          1.4880   0.5900  1.005
# I     0.725      0.55   0.220        2.0495          0.7735   0.4405  0.655
# M     0.780      0.63   0.515        2.8255          1.3510   0.7600  0.897
#
#      n_rings
# sex
# F         29
# I         21
# M         27

# %%
groupby_obj.count()
# Out:
#      length  diameter  height  weight_whole  weight_shucked  viscera  shell  \
# sex
# F      1307      1307    1307          1307            1307     1307   1307
# I      1342      1342    1342          1342            1342     1342   1342
# M      1528      1528    1528          1528            1528     1528   1528
#
#      n_rings
# sex
# F       1307
# I       1342
# M       1528

# %%
df.groupby('sex').count()['length']
# Out:
# sex
# F    1307
# I    1342
# M    1528
# Name: length, dtype: int64

# %%
# Note we can also group by multiple columns by passing them in a list. It will group by 
# the first column passed in first, and then the second after that (i.e. it will group by 
# the second within the group by of the first). 
df.groupby(['sex', 'n_rings']).count()['weight_whole']
# Out:
# sex  n_rings
# F    5            4
#      6           16
#      7           44
#      8          122
#      9          238
#                ...
# M    22           3
#      23           3
#      24           1
#      26           1
#      27           1
# Name: weight_whole, Length: 68, dtype: int64

# %%
df.sort_values('length').head(15) # Note: this is ascending by default.
# df.sort_values('length', ascending=False) # here we change ascending to false.
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010   0.0005
# 238    I   0.110     0.090   0.030        0.0080          0.0025   0.0020
# 2114   I   0.130     0.095   0.035        0.0105          0.0050   0.0065
# 237    I   0.130     0.100   0.030        0.0130          0.0045   0.0030
# 1986   I   0.135     0.130   0.040        0.0290          0.0125   0.0065
# 1429   I   0.140     0.105   0.035        0.0140          0.0055   0.0025
# 3899   I   0.140     0.105   0.035        0.0145          0.0050   0.0035
# 719    I   0.150     0.100   0.025        0.0150          0.0045   0.0040
# 2381   M   0.155     0.115   0.025        0.0240          0.0090   0.0050
# 696    I   0.155     0.105   0.050        0.0175          0.0050   0.0035
# 526    M   0.155     0.110   0.040        0.0155          0.0065   0.0030
# 720    I   0.160     0.110   0.025        0.0180          0.0065   0.0055
# 239    I   0.160     0.120   0.035        0.0210          0.0075   0.0045
# 1987   I   0.160     0.110   0.025        0.0195          0.0075   0.0050
# 3902   I   0.160     0.120   0.020        0.0180          0.0075   0.0045
#
#        shell  n_rings
# 236   0.0015        1
# 238   0.0030        3
# 2114  0.0035        4
# 237   0.0040        3
# 1986  0.0080        4
# 1429  0.0040        3
# 3899  0.0050        4
# 719   0.0050        2
# 2381  0.0075        5
# 696   0.0050        4
# 526   0.0050        3
# 720   0.0050        3
# 239   0.0050        5
# 1987  0.0060        4
# 3902  0.0050        4

# %%
# Sort by multiple columns
df.sort_values(['length', 'diameter'], ascending=False).head(15) # ascending=False will apply to both columns.
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 1428   F   0.815     0.650   0.250        2.2550          0.8905   0.4200
# 2334   F   0.800     0.630   0.195        2.5260          0.9330   0.5900
# 1209   F   0.780     0.630   0.215        2.6570          1.4880   0.4985
# 3715   M   0.780     0.600   0.210        2.5480          1.1945   0.5745
# 1763   M   0.775     0.630   0.250        2.7795          1.3485   0.7600
# 2090   M   0.775     0.570   0.220        2.0320          0.7350   0.4755
# 1762   M   0.770     0.620   0.195        2.5155          1.1155   0.6415
# 4148   M   0.770     0.605   0.175        2.0505          0.8005   0.5260
# 2625   M   0.770     0.600   0.215        2.1945          1.0515   0.4820
# 1052   M   0.765     0.600   0.220        2.3020          1.0070   0.5090
# 2624   M   0.765     0.585   0.180        2.3980          1.1280   0.5120
# 1985   M   0.760     0.605   0.215        2.1730          0.8010   0.4915
# 3896   M   0.760     0.575   0.190        1.8290          0.7035   0.3860
# 1207   F   0.755     0.625   0.210        2.5050          1.1965   0.5130
# 1208   M   0.755     0.580   0.205        2.0065          0.8295   0.4015
#
#        shell  n_rings
# 1428  0.7975       14
# 2334  0.6200       23
# 1209  0.5860       11
# 3715  0.6745       11
# 1763  0.5780       12
# 2090  0.6585       17
# 1762  0.6420       12
# 4148  0.3550       11
# 2625  0.5840       10
# 1052  0.6205       12
# 2624  0.5335       12
# 1985  0.6460       13
# 3896  0.5600       14
# 1207  0.6785       11
# 1208  0.5950       10

# %%
# we can rename columns with `.rename()`
df.rename(columns={'n_rings': 'nr_rings'}, inplace=True)
df.head()
# Out:
#   sex  length  diameter  height  weight_whole  weight_shucked  viscera  shell  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245   0.1010  0.150
# 1   M   0.350     0.265   0.090        0.2255          0.0995   0.0485  0.070
# 2   F   0.530     0.420   0.135        0.6770          0.2565   0.1415  0.210
# 3   M   0.440     0.365   0.125        0.5160          0.2155   0.1140  0.155
# 4   I   0.330     0.255   0.080        0.2050          0.0895   0.0395  0.055
#
#    nr_rings
# 0        15
# 1         7
# 2         9
# 3        10
# 4         7

# %%
# with `.eval()` we can create new columns
# remember that in the description it is stated that the age of the snails can be calculated by adding 1.5 to the nr. of rings
df.eval('age = nr_rings + 1.5', inplace = True)
df.columns
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'weight_whole', 'weight_shucked',
#        'viscera', 'shell', 'nr_rings', 'age'],
#       dtype='object')

# %%
df.eval('weight_per_hight = weight_whole / diameter', inplace = True)
df.columns
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'weight_whole', 'weight_shucked',
#        'viscera', 'shell', 'nr_rings', 'age', 'weight_per_hight'],
#       dtype='object')

# %%
# the age is our newly created feature, therefore "nr_rings" does not contain any further information
# with axis=1 we define that we are dropping a column, not a row
# by default it would be axis=0
df.drop('nr_rings', axis=1)
# Out:
#      sex  length  diameter  height  weight_whole  weight_shucked  viscera  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245   0.1010
# 1      M   0.350     0.265   0.090        0.2255          0.0995   0.0485
# 2      F   0.530     0.420   0.135        0.6770          0.2565   0.1415
# 3      M   0.440     0.365   0.125        0.5160          0.2155   0.1140
# 4      I   0.330     0.255   0.080        0.2050          0.0895   0.0395
# ...   ..     ...       ...     ...           ...             ...      ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700   0.2390
# 4173   M   0.590     0.440   0.135        0.9660          0.4390   0.2145
# 4174   M   0.600     0.475   0.205        1.1760          0.5255   0.2875
# 4175   F   0.625     0.485   0.150        1.0945          0.5310   0.2610
# 4176   M   0.710     0.555   0.195        1.9485          0.9455   0.3765
#
#        shell   age  weight_per_hight
# 0     0.1500  16.5          1.408219
# 1     0.0700   8.5          0.850943
# 2     0.2100  10.5          1.611905
# 3     0.1550  11.5          1.413699
# 4     0.0550   8.5          0.803922
# ...      ...   ...               ...
# 4172  0.2490  12.5          1.971111
# 4173  0.2605  11.5          2.195455
# 4174  0.3080  10.5          2.475789
# 4175  0.2960  11.5          2.256701
# 4176  0.4950  13.5          3.510811
#
# [4177 rows x 10 columns]

# %%
df.columns # Wait, the nr_rings column is still there... why? 
           # It's because we didn't tell it drop inplace.
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'weight_whole', 'weight_shucked',
#        'viscera', 'shell', 'nr_rings', 'age', 'weight_per_hight'],
#       dtype='object')

# %%
df.drop('nr_rings', inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['sex', 'length', 'diameter', 'height', 'weight_whole', 'weight_shucked',
#        'viscera', 'shell', 'age', 'weight_per_hight'],
#       dtype='object')

# %%
# Notice the addition of the inplace argument here. 
# if you try to fill nans will some value: the first argument is the inserted value
df.fillna(-1, inplace=True)
# dropna() will drop the whole row, if nans are present
df.dropna(inplace=True)

# %%
df['length'] <= 0.3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4172    False
# 4173    False
# 4174    False
# 4175    False
# 4176    False
# Name: length, Length: 4177, dtype: bool

# %%
df['length'] <= 0.3
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4172    False
# 4173    False
# 4174    False
# 4175    False
# 4176    False
# Name: length, Length: 4177, dtype: bool

# %%
df.groupby('sex').count()['age']
# Out:
# sex
# F    1307
# I    1342
# M    1528
# Name: age, dtype: int64
